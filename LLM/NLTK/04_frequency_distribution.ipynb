# %%
import nltk
from nltk.book import *

# %%
freq_dist = FreqDist(text1)
print(freq_dist)

vocab1 = freq_dist.keys()
# Text1(Mobi Dick)에서 사용된 유일한 단어들의 갯수....
print('The word count which was used in Text1', len(vocab1))
print(list(vocab1)[:30])
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>
# The word count which was used in Text1 19317
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', '1851', ']', 'ETYMOLOGY', '.', '(', 'Supplied', 'a', 'Late', 'Consumptive', 'Usher', 'to', 'Grammar', 'School', ')', 'The', 'pale', '--', 'threadbare', 'in', 'coat', ',', 'heart', 'body', 'and']

# %%
freq_dist.plot(20)
#freq_dist.items()
freq_dist['he']

#vocab1
#freq_dist.hexas()
#dir(freq_dist)
from nltk.corpus import stopwords
import string

english_stopwords = set(stopwords.words('english'))
english_stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
punctuation = set(string.punctuation)
punctuation
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
from nltk_utils import *

ss_frq_dist = FreqDist(text2)
unique_words = remove_english_stopwords(ss_frq_dist)
print(unique_words[:50])
# Out:
# Unique word counts:  6833
# Total word counts after removing english stopwords and punctuation 6545
# ['Sense', 'Sensibility', 'Jane', 'Austen', '1811', 'CHAPTER', '1', 'family', 'Dashwood', 'long', 'settled', 'Sussex', 'estate', 'large', 'residence', 'Norland', 'Park', 'centre', 'property', 'many', 'generations', 'lived', 'respectable', 'manner', 'engage', 'general', 'good', 'opinion', 'surrounding', 'acquaintance', 'late', 'owner', 'single', 'man', 'advanced', 'age', 'years', 'life', 'constant', 'companion', 'housekeeper', 'sister', 'death', 'happened', 'ten', 'produced', 'great', 'alteration', 'home', 'supply']

# %%
#ss_frq_dist.items()
ss_frq_dist.hapaxes()
# Out:
# ['Sense',
#  'Sensibility',
#  'Jane',
#  'Austen',
#  '1811',
#  ']',
#  'generations',
#  'inheritor',
#  'bequeath',
#  'Gentleman',
#  'relish',
#  'devolved',
#  'inheriting',
#  'moiety',
#  'bequest',
#  'sale',
#  'articulation',
#  'economically',
#  'tardy',
#  'survived',
#  'including',
#  'legacies',
#  'urgency',
#  'prudently',
#  'caricature',
#  'warmed',
#  'Three',
#  'successively',
#  'funeral',
#  'dispute',
#  'decease',
#  'indelicacy',
#  'keen',
#  'whomsoever',
#  'immoveable',
#  'acutely',
#  'qualified',
#  'counsellor',
#  'joys',
#  'afflicted',
#  'strive',
#  'humored',
#  'imbibed',
#  'romance',
#  'thirteen',
#  '2',
#  'installed',
#  'degraded',
#  'seasons',
#  'alloy',
#  'impoverishing',
#  'headed',
#  'stipulate',
#  'LET',
#  'diminished',
#  'REALLY',
#  'strikes',
#  'Fifteen',
#  'healthy',
#  'clogged',
#  'superannuated',
#  'amazing',
#  'restriction',
#  'drains',
#  'bind',
#  'inconvenient',
#  'enlarge',
#  'sixpence',
# ...

# %%
text2.common_contexts('unapprehensive')
# Out:
# ('The following word(s) were not found:', 'u n a p p r e h e n s i v e')

# %%
text1.common_contexts('swallowed')
# Out:
# No common contexts were found

# %%
text1.common_contexts('unapprehensive')
# Out:
# ('The following word(s) were not found:', 'u n a p p r e h e n s i v e')

# %%
text1.concordance('swallowed')
# Out:
# Displaying 13 of 13 matches:
# ) mouth , are immediately lost and swallowed up , the sea - gudgeon retires int
# ES ' S LEVIATHAN . " Silly Mansoul swallowed it without chewing , as if it had
# d came upon him in the whale , and swallowed him down to living gulfs of doom ,
#  ; and chewed it noiselessly ; and swallowed it , not without circumspection .
#  were nothing ; the fears of being swallowed up by some dreadful tempest , or d
# company the live ground opened and swallowed them up for ever ; yet not a moder
# hen sank out of sight like a tower swallowed up . " There go flukes !" was the
# ld watch that the whale might have swallowed , and which he was fearful of brea
# r own ; till those entrails seemed swallowed over and over again by the same mo
# doer of rejoicing good deeds , was swallowed down and thrown up by a whale ; st
#  , if I remember right : Jonah was swallowed by the whale in the Mediterranean
# ...
