# %%
# ReLU (rectified linear unit)
import torch
import matplotlib.pyplot as plt

relu = torch.nn.ReLU()
x = torch.arange(-5., 5., 0.1)
y = relu(x)

# Plot of ReLU activation
plt.plot(x.numpy(), y.numpy())
plt.show()
